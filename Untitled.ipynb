# %%
from pylab import*

# %%
x=linspace(1,10)

# %%
y=1/(x**2)

# %%
plot(x,y)

# %%
z=linspace(0,100,1001)
print(z)
# Out:
# [  0.    0.1   0.2 ...  99.8  99.9 100. ]

# %%
z[6]
# Out:
# 0.6000000000000001

# %%
plot(x,x**2)

# %%
def mi_sin_p(x,n=10):
    f = 0
    for n in range(n):
        f += ((-1)**n) * ((x**(2*n+1))/(2*n+1))
    return f

# %%
plot(x,mi_sin_p(x))
